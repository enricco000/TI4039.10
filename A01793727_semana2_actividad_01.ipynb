# %% [markdown]
# <a href="https://colab.research.google.com/github/enricco000/TI4039.10/blob/main/A01793727_semana2_actividad_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Maestría en Inteligencia Artificial Aplicada**
# ##**Curso: Procesamiento de Lenguaje Natural (NLP)**
# ###Tecnológico de Monterrey
# ###Prof Luis Eduardo Falcón Morales
#
# ## **Adtividad de la Semana 02**
# ###**Introducción al procesamiento de texto.**

# %% [markdown]
# En esta actividad deberás utilizar los datos del siguiente archivo que se encuentra en Canvas:
#
# MNA_NLP_semana_02_Actividad_datos.txt
#
# El archivo contiene comentarios en inglés sobre servicios de comida de la página de Yelp: https://www.yelp.com/ .
#
# Son mil comentarios y forman parte del conjunto de datos que se encuentra en el Machine Learning Repository de la UCI, llamado "Sentiment Labelled Sentences": https://archive.ics.uci.edu/ml/datasets/Sentiment+Labelled+Sentences#

# %% [markdown]
# #**Parte 1. Cargamos los datos.**

# %% [markdown]
# Cargar los datos del archivo indicado y obtener una lista de longitud de 1000 strings/comentarios.
#
# Por el momento solamente requerimos las bibliotecas de Numpy y re, para el manejo de los arreglos y de las expresiones regulares en Python.
#
# En particular, no necesitarás en esta actividad la biblioteca de Pandas.
#
# ###**NOTA: En esta actividad no debes importar nada más, con estas dos bibliotecas será *suficiente*.**

# %%
import numpy as np    # importamos Numpy para el manejo de los arreglos.
import re             # importamos re para el manejo de las expresiones regulares.

# %%
# Ejecuta las siguientes instrucciones para cargar la información del achivo dado:

with open('MNA_NLP_semana_02_Actividad_datos.txt',        # puedes actualizar la ruta a tu archivo, en dado caso.
          mode='r',     # abrimos el archivo en modo lectura.
          ) as f:
    docs = f.readlines()    # separamos cada comentario por líneas

f.close()  # ya que tenemos la información en la variable docs, cerramos el archivo

# %%
type(docs) == list   # Verifica que tu variable "docs" es una lista
# Out:
# True

# %%
len(docs)==1000  # verifica que la longitud de "docs" es de mil comentarios.
# Out:
# True

# %%
docs[0:10]     # observa algunos de los primeros comentarios
# Out:
# ['Wow... Loved this place.\n',
#  'Crust is not good.\n',
#  'Not tasty and the texture was just nasty.\n',
#  'Stopped by during the late May bank holiday off Rick Steve recommendation and loved it.\n',
#  'The selection on the menu was great and so were the prices.\n',
#  'Now I am getting angry and I want my damn pho.\n',
#  "Honeslty it didn't taste THAT fresh.)\n",
#  'The potatoes were like rubber and you could tell they had been made up ahead of time being kept under a warmer.\n',
#  'The fries were great too.\n',
#  'A great touch.\n']

# %% [markdown]
# #**Parte 2: sección de preguntas (regex).**

# %% [markdown]
# ##**Instrucciones:**
#
# ###**A continuación deberás contestar cada una de las preguntas que te piden usando expresiones regulares (regex).**
#
# ###**Por el momento no hay restricción en cuanto al número de líneas de código que agregues, pero trata de incluir las mínimas posibles.**

# %% [markdown]
# *   **Pregunta 1.**
#
# Busca y elimina todos los saltos de línea '\n' que se encuentran al final de cada comentario.
#
# Una vez finalizado, imprime los primeros 10 comentarios del resultado obtenido.

# %%
docs = [re.sub("\n$", "", x) for x in docs]
print(docs[0:10])
# Out:
# ['Wow... Loved this place.', 'Crust is not good.', 'Not tasty and the texture was just nasty.', 'Stopped by during the late May bank holiday off Rick Steve recommendation and loved it.', 'The selection on the menu was great and so were the prices.', 'Now I am getting angry and I want my damn pho.', "Honeslty it didn't taste THAT fresh.)", 'The potatoes were like rubber and you could tell they had been made up ahead of time being kept under a warmer.', 'The fries were great too.', 'A great touch.']

# %% [markdown]
# *   **Pregunta 2.**
#
# Busca e imprime todas las palabras que terminan con dos o más signos de admiración seguidos, por ejemplo "!!!".
#
# Debes imprimir tanto la palabra como la totalidad de signos de admiración que le siguen.
#
# Indica cuántos resultados obtuviste.

# %%
pattern = r"\b\w*!{2,}\B"
i = 0
for x in docs:
    matches = re.findall(pattern, x)
    if matches:
        for each in matches:
            bangs = each.count("!")
            print(f"{each} ({bangs} veces)")
            i += 1
print(f"\n-> Total: {i}")
# Out:
# Firehouse!!!!! (5 veces)
# APPETIZERS!!! (3 veces)
# amazing!!! (3 veces)
# buffet!!! (3 veces)
# good!! (2 veces)
# it!!!! (4 veces)
# DELICIOUS!! (2 veces)
# amazing!! (2 veces)
# shawarrrrrrma!!!!!! (6 veces)
# yucky!!! (3 veces)
# steak!!!!! (5 veces)
# delicious!!! (3 veces)
# far!! (2 veces)
# biscuits!!! (3 veces)
# dry!! (2 veces)
# disappointing!!! (3 veces)
# awesome!! (2 veces)
# Up!! (2 veces)
# FLY!!!!!!!! (8 veces)
# here!!! (3 veces)
# great!!!!!!!!!!!!!! (14 veces)
# packed!! (2 veces)
# otherwise!! (2 veces)
# amazing!!!!!!!!!!!!!!!!!!! (19 veces)
# style!! (2 veces)
# disappointed!! (2 veces)
#
# -> Total: 26

# %% [markdown]
# *   **Pregunta 3.**
#
# Busca e imprime todas las palabras que están escritas totalmente en mayúsculas. Cada coincidencia debe ser una sola palabra.
#
# Indica cuántas palabras encontraste.

# %%
pattern = r"\b[A-Z]+\b"
i = 0
for x in docs:
    matches = re.findall(pattern, x)
    if matches:
        for each in matches:
            # removing I's from the print, but not the count
            if each != 'I':
              print(each)
            i += 1
print(f"\n-> Total: {i}")
# Out:
# THAT
# A
# APPETIZERS
# A
# WILL
# NEVER
# EVER
# STEP
# FORWARD
# IN
# IT
# AGAIN
# LOVED
# AND
# REAL
# BITCHES
# NYC
# STALE
# DELICIOUS
# WORST
# EXPERIENCE
# EVER
# ALL
# BARGAIN
# TV
# NONE
# M
# FREEZING
# AYCE
# FLAVOR
# NEVER
# BBQ
# A
# UNREAL
# OMG
# BETTER
# BLAND
# RUDE
# INCONSIDERATE
# MANAGEMENT
# WILL
# NEVER
# EVER
# GO
# BACK
# AND
# HAVE
# TOLD
# MANY
# PEOPLE
# WHAT
# HAD
# HAPPENED
# TOTAL
# WASTE
# OF
# TIME
# FS
# AZ
# LOVED
# CONCLUSION
# BEST
# GO
# NOW
# A
# GC
# AVOID
# THIS
# ESTABLISHMENT
# A
# AN
# HOUR
# NASTY
# OMG
# NO
# BEST
# THE
# OWNERS
# REALLY
# REALLY
# PERFECT
# SCREAMS
# LEGIT
# MGM
# A
# BEST
# T
# A
# FLY
# A
# FLY
# FANTASTIC
# GREAT
# OK
# WAY
# MUST
# HAVE
# OK
# OVERPRICED
# BARE
# HANDS
# WEAK
# SHOULD
# RI
# VERY
# NOT
# A
#
# -> Total: 455

# %% [markdown]
# *   **Pregunta 4.**
#
# Busca e imprime los comentarios en donde todos los caracteres alfabéticos (letras) están en mayúsculas.
#
# Cada coincidencia encontrada debe ser todo el comentario/enunciado.
#
# Indica cuántos resultados obtuviste.

# %%
i = 0
for x in docs:
    if(x.upper() == x):
      print(x)
      i+=1
print(f"\n-> Total: {i}")
# Out:
# DELICIOUS!!
# RUDE & INCONSIDERATE MANAGEMENT.
# WILL NEVER EVER GO BACK AND HAVE TOLD MANY PEOPLE WHAT HAD HAPPENED.
# TOTAL WASTE OF TIME.
# AVOID THIS ESTABLISHMENT!
#
# -> Total: 5

# %% [markdown]
# *   **Pregunta 5.**
#
# Busca e imprime todas las palabras que tengan una vocal acentuada, del tipo á, é, í, ó, ú.
#
# Indica cuántos resultados obtuviste.

# %%
pattern = r"\b\w*[áéíóú]\w*\b"
i = 0
for x in docs:
    matches = re.findall(pattern, x)
    if matches:
        for each in matches:
            print(each)
            i += 1
print(f"\n-> Total: {i}")
# Out:
# fiancé
# Café
# puréed
#
# -> Total: 3

# %% [markdown]
# *   **Pregunta 6.**
#
# Busca e imprime todas las cantidades numéricas monetarias, enteras o con decimales, que inician con el símbolo $\$$.
#
# Indica cuántos resultados obtuviste.

# %%
pattern = r"\$[\d,]+(?:\.\d+)?"
i = 0
for x in docs:
    matches = re.findall(pattern, x)
    if matches:
        for each in matches:
            print(each)
            i += 1
print(f"\n-> Total: {i}")
# Out:
# $20,
# $4.00
# $17
# $3
# $35
# $7.85
# $12,
# $11.99
#
# -> Total: 8

# %% [markdown]
# *   **Pregunta 7.**
#
# Busca e imprime todas las palabras que sean variantes de la palabra "love", sin importar si incluyen mayúsculas o minúsculas, o la manera en que esté conjugada o alguna otra variación que se haga con dicha palabra.
#
# Indica cuántos resultados obtuviste.

# %%
pattern = r"\blov\w*\b"
all_ = []
for x in docs:
    comment_matches = re.findall(pattern, x, flags=re.IGNORECASE)
    if comment_matches:
        for each in comment_matches:
            all_.append(each)
all_ = list(set(all_))
print("\n-> Encontrados:", all_)
print("\n-> Ocurrencias:", len(all_))
# Out:
# -> Encontrados: ['LOVED', 'lovely', 'lover', 'Loved', 'love', 'loving', 'loves', 'Love', 'lovers', 'loved']
#
# -> Ocurrencias: 10

# %% [markdown]
# *   **Pregunta 8.**
#
# Busca e imprime todas las palabras, variantes de "so" y "good", que tengan dos o más "o" en "so" y 3 o más "o" en good.
#
# Indica cuántas encontraste.

# %%
pattern = r"\bso\w*o\b|\bg\w*o\w*o{2,}\w*o*d+\w*\b"
all_ = []
for x in docs:
    comment_matches = re.findall(pattern, x, flags=re.IGNORECASE)
    if comment_matches:
        for each in comment_matches:
            all_.append(each)
all_ = list(set(all_))
print("\n-> Encontrados:", all_)
print("\n-> Ocurrencias:", len(all_))
# Out:
# -> Encontrados: ['soooooo', 'gooodd', 'Sooooo', 'soooo']
#
# -> Ocurrencias: 4

# %% [markdown]
# *   **Pregunta 9.**
#
# Busca e imprime todas las palabras que tengan una longitud mayor estrictamente a 10 caracteres alfabéticos.
#
# No se consideran los signos de puntuación o caracteres especiales en la longitud de estas cadenas, solo caracteres alfabéticos en mayúsculas o minúsculas.
#
# Indica la cantidad de palabras encontradas.

# %%
pattern = r"\b[a-zA-Z]{11,}\b"
all_ = []
for x in docs:
    comment_matches = re.findall(pattern, x)
    if comment_matches:
        for each in comment_matches:
            all_.append(each)
all_ = list(set(all_))
print("\n-> Encontrados:", all_)
print("\n-> Ocurrencias:", len(all_))
# Out:
# -> Encontrados: ['vinaigrette', 'Furthermore', 'imaginative', 'compliments', 'shawarrrrrrma', 'restaurants', 'inexpensive', 'INCONSIDERATE', 'unprofessional', 'Mediterranean', 'underwhelming', 'highlighted', 'exceptional', 'caterpillar', 'ingredients', 'grandmother', 'transcendant', 'ESTABLISHMENT', 'imagination', 'connoisseur', 'unsatisfying', 'hospitality', 'deliciously', 'disrespected', 'maintaining', 'profiterole', 'neighborhood', 'circumstances', 'recommended', 'unfortunately', 'relationship', 'Unfortunately', 'recommending', 'experienced', 'experiencing', 'informative', 'Veggitarian', 'acknowledged', 'establishment', 'unexperienced', 'deuchebaggery', 'traditional', 'outrageously', 'Outstanding', 'anticipated', 'ventilation', 'disappointment', 'opportunity', 'outstanding', 'calligraphy', 'considering', 'beautifully', 'cheesecurds', 'Interesting', 'disappointed', 'Disappointed', 'disgraceful', 'reservation', 'comfortable', 'undercooked', 'suggestions', 'Philadelphia', 'expectatio
# ...

# %% [markdown]
# *   **Pregunta 10.**
#
# Busca e imprime todas las palabras que inician con una letra mayúscula y terminan con una minúscula, pero que además no sea la primera palabra del comentario/string.
#
# Indica la cantidad de resultados obtenidos.

# %%
pattern = r'\b([A-Z][a-z]+[a-z])\b'
condition=r"^\w+"
total_results = 0
for x in docs:
    x = x.replace('"', '')
    x = x.replace("'", '')
    words = re.findall(pattern, x)
    first=re.findall(condition, x)
    try:
      if(first[0] in words):
        words.remove(first[0])
    except:
      if(len(words)!=0):
        print(f"""->
      Frase: '{x}'
        Palabras: {words}""")
        total_results += len(words)
      continue
    if(len(words)!=0):
      print(f"""->
      Frase: '{x}'
        Palabras: {words}""")
      total_results += len(words)
print(f"\n-> Total: {total_results}")
# Out:
# ->
#       Frase: 'Wow... Loved this place.'
#         Palabras: ['Loved']
# ->
#       Frase: 'Stopped by during the late May bank holiday off Rick Steve recommendation and loved it.'
#         Palabras: ['May', 'Rick', 'Steve']
# ->
#       Frase: 'I tried the Cape Cod ravoli, chicken,with cranberry...mmmm!'
#         Palabras: ['Cape', 'Cod']
# ->
#       Frase: 'This place is not worth your time, let alone Vegas.'
#         Palabras: ['Vegas']
# ->
#       Frase: 'The Burrittos Blah!'
#         Palabras: ['Burrittos', 'Blah']
# ->
#       Frase: 'I could care less... The interior is just beautiful.'
#         Palabras: ['The']
# ->
#       Frase: '- They never brought a salad we asked for.'
#         Palabras: ['They']
# ->
#       Frase: 'This hole in the wall has great Mexican street tacos, and friendly staff.'
#         Palabras: ['Mexican']
# ->
# ...

# %% [markdown]
# *   **Pregunta 11.**
#
# Busca e imprime la secuencia de dos o más palabras que están separadas por un guion, "-", sin que tengan espacios en blanco entre ellas.
#
# Por ejemplo "Go-Kart" sería válido, pero "Go  -Kart" o "Go  -  Kart" no lo serían.
#
# Indica la cantidad de resultados obtenidos.

# %%
pattern = r'\b\w+-\w+(?!\w)'
i = 0
for x in docs:
    all_ = re.findall(pattern, x)
    i += len(all_)
    for each in all_:
        print(each)
print(f"\n-> Total: {i}")
# Out:
# flat-lined
# hands-down
# must-stop
# sub-par
# Service-check
# in-house
# been-stepped
# in-and
# tracked-everywhere
# multi-grain
# to-go
# non-customer
# High-quality
# sit-down
# over-whelm
# low-key
# non-fancy
# golden-crispy
# over-priced
# over-hip
# under-services
#
# -> Total: 21

# %% [markdown]
# *   **Pregunta 12.**
#
# Busca e imprime todas las palabras que terminan en "ing" o "ed".
#
# Indica la cantidad de palabras que encontraste de cada una.

# %%
ing = 0
ed = 0
for comment in docs:
    words = comment.split()
    for word in words:
        if re.search(r'\b\w+(?:ing|ed)\b', word):
            if word.endswith('ing'):
                ing += 1
            else:
                ed += 1
            print(word)
print(f"\n-> Terminados en 'ing': {ing}")
print(f"\n-> Terminados en 'ed': {ed}")
# Out:
# Loved
# Stopped
# during
# loved
# getting
# being
# ended
# being
# overpriced.
# tried
# disgusted
# shocked
# recommended.
# amazing."
# performed.
# red
# asked
# running
# overwhelmed."
# redeeming
# grossed
# melted
# getting
# provided
# thing
# cooked
# dressing
# refreshing."
# ordered
# running
# realized
# "Loved
# flat-lined
# cooked."
# ripped
# ripped,
# petrified
# amazing
# included
# expected."
# nothing
# appalling
# seasoned
# cheated
# wasting
# eating
# going
# Coming
# experiencing
# underwhelming
# walked
# smelled
# eating.
# raving
# tailored
# spring
# unsatisfying.
# amazing!!!
# Everything
# disappointing
# dining
# flirting
# arrived
# roasted
# added
# thing
# coming."
# cooked
# playing.
# passed
# ordering
# arriving,
# liked
# disappointing."
# managed
# served
# preparing
# loving
# liking
# reviewing..
# venturing
# overpriced
# including
# during
# checked
# disappointed
# red
# decorated.
# changing,
# going
# considering
# served
# coming
# ...

# %% [markdown]
# #**Parte 3. Proceso de limpieza.**

# %% [markdown]
# *   **Pregunta 13.**
#
# Ahora realiza un proceso de limpieza del corpus que incluya los siguientes procesos:
#
# *   Solo se deben considerar caracteres alfabéticos. Es decir, se eliminan todos los signos de puntuación y caracteres especiales.
# *   Todos los caracteres alfabéticos se transforman a minúsculas.
# *   Se deben eliminar todos los espacios en blanco adicionales que se puedan encontrar en cada comentario.
#
# Al finalizar dicho proceso de limpieza, imprime el resultado de los primeros 10 comentarios resultantes.

# %%
def clean(x):
    x = re.sub(r'[^a-zA-Z\s]', '', x)
    return re.sub(r'\s+', ' ', x.lower()).strip()

coms = [clean(x) for x in docs]

# Print first 10 resulting comments
for i, x in enumerate(coms[:10]):
    print(f"Comment {i+1}: {x}")
# Out:
# Comment 1: wow loved this place
# Comment 2: crust is not good
# Comment 3: not tasty and the texture was just nasty
# Comment 4: stopped by during the late may bank holiday off rick steve recommendation and loved it
# Comment 5: the selection on the menu was great and so were the prices
# Comment 6: now i am getting angry and i want my damn pho
# Comment 7: honeslty it didnt taste that fresh
# Comment 8: the potatoes were like rubber and you could tell they had been made up ahead of time being kept under a warmer
# Comment 9: the fries were great too
# Comment 10: a great touch

# %% [markdown]
# *   **Pregunta 14.**
#
# Con el resultado de la limpieza obtenido en la pregunta anterior, realiza ahora un proceso de tokenización por palabras del corpus.
#
# Es decir, al final de este proceso de tokenización, debes tener como resultado una lista de listas, donde cada comentario estará tokenizado por palabras.
#
# Al terminar calcula el total de tokens obtenido en todo el corpus.

# %%
tokenized_comments = []
for x in coms:
    tokens = x.split()
    tokenized_comments.append(tokens)

total_tokens = sum(len(comment_tokens) for comment_tokens in tokenized_comments)
print(f"\n-> Tokens: {total_tokens}")
# Out:
# -> Tokens: 10777

# %%
import itertools

tokens = set(itertools.chain(*tokenized_comments))
total_tokens = len(tokens)
print(f"Total Tokens: {total_tokens}")
# Out:
# Total Tokens: 2051

# %% [markdown]
# *   **Pregunta 15.**
#
# Finalmente, en este ejercicio definiremos nuestro conjunto de palabras "stopwords", las cuales deberás eliminar de todo el corpus.
#
# Recuerda que ejemplos de stopwords son artículos, adverbios, conectivos, etcétera, que tienen frecuencias de aparición muy altas en cualquier documento, pero que no brindan mucho significado en cuanto al significado de un enunciado.
#
# Con base a la lista de stopwords que se te proporciona, realiza un proceso de limpieza eliminando todas estas palabras del corpus obtenido en el ejercicio anterior.
#
# Obtener cuántos tokens/palabras quedan finalmente en todo el corpus.
#
# Obtener cuántos de estos tokens/palabras son diferentes, es decir, cuántos tokens únicos tendrá lo que llamaremos más adelante nuestro vocabulario.

# %%
# Considera la siguiente lista como tu conjunto de stopwords:
mis_stopwords = ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'your', 'yours', 'he', 'him', 'his', 'himself', 'she', 'her', 'hers', 'herself', 'it', 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'should', 'now', 'll']

# %%
clean_tokens = []
for each in tokens:
    if each.lower() not in mis_stopwords:
        clean_tokens.append(each.lower())
print(clean_tokens)
print(f"\n-> Total: {len(clean_tokens)}")
# Out:
# ['wrapped', 'nasty', 'orders', 'nutshell', 'compliments', 'guess', 'properly', 'highlighted', 'heart', 'valley', 'updatewent', 'trips', 'anyways', 'suck', 'first', 'hamburger', 'started', 'venture', 'dried', 'may', 'heat', 'businesses', 'hiro', 'ranch', 'id', 'cook', 'qualified', 'services', 'avocado', 'eating', 'five', 'arent', 'hopes', 'loved', 'yucky', 'huge', 'furthermore', 'tapas', 'paid', 'experiencing', 'delightful', 'shall', 'boring', 'item', 'club', 'japanese', 'donut', 'pork', 'mall', 'foods', 'gratuity', 'monster', 'hereas', 'teeth', 'dedicated', 'cocktails', 'really', 'sever', 'yaall', 'place', 'suggest', 'reasonable', 'gets', 'philadelphia', 'used', 'incredible', 'customize', 'generous', 'halibut', 'duo', 'noca', 'marrow', 'listed', 'par', 'arepas', 'try', 'filling', 'voodoo', 'relaxed', 'pured', 'off', 'amount', 'disappoint', 'grab', 'flavorless', 'ladies', 'seemed', 'case', 'letdown', 'peanut', 'strange', 'felt', 'hut', 'zero', 'marys', 'dark', 'far', 'restaurant', 'ho
# ...

# %% [markdown]
# *   **Comentarios**
#
# Incluye finalmente tus comentarios de la actividad.

# %% [markdown]
# Regex es de las cosas que siempre me han parecido más complicadas, y creo que pocas veces lo he usado de forma tan extensa. Algunos de estos ejercicios se parecen a retos de leetcode; no sé si la dificultad de ellos se justifica...

# %% [markdown]
# ##**Fin de la Actividad de la semana 2.**
